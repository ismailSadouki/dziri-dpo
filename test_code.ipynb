# %%
import os
# !export "FISH_API_KEY="

os.environ["FISH_API_KEY"] ="sk-fish-F1crC9-ZHp9CgnRx-LLkHhgRLxbeo7BTKS6efJDjUqM"
print(os.environ.get("FISH_API_KEY"))
# Out:
# sk-fish-F1crC9-ZHp9CgnRx-LLkHhgRLxbeo7BTKS6efJDjUqM

# %%
from rick_voice import RickVoice


# export FISH_API_KEY="sk-fish-F1crC9-ZHp9CgnRx-LLkHhgRLxbeo7BTKS6efJDjUqM"

rick = RickVoice()
rick.play("I turned myself into a pickle, Morty!")
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[10], line 7
#       4 # export FISH_API_KEY="sk-fish-F1crC9-ZHp9CgnRx-LLkHhgRLxbeo7BTKS6efJDjUqM"
#       6 rick = RickVoice()
# ----> 7 rick.play("I turned myself into a pickle, Morty!")
#
# File ~/miniconda/envs/ml-dl/lib/python3.10/site-packages/rick_voice/core.py:115, in RickVoice.play(self, text)
#     109 """Speak text through speakers in Rick's voice.
#     110
#     111 Args:
#     112     text: Text to speak.
#     113 """
#     114 prepared = self._prepare_text(text)
# --> 115 self.provider.play(prepared)
#
# File ~/miniconda/envs/ml-dl/lib/python3.10/site-packages/rick_voice/providers/fish_audio.py:78, in FishAudioProvider.play(self, text)
#      75 try:
#      76     from fishaudio.utils import play
# ---> 78     audio = self.synthesize(text)
#      79     play(audio)
#      80 except ImportError:
# ...

# %%
from rick_voice import RickVoice

rick = RickVoice()
rick.play("I turned myself into a pickle, Morty!")
